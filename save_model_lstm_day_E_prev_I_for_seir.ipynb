# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import time
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler

# %%
###############################################################################
# 1. Data preparation
###############################################################################
def create_sequences(data, window_size):
    """
    Convert a multivariate sequence into samples of shape (window_size, n_features).
    The target is the last column (log_beta).
    """
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i : i + window_size, :-1])  # use first 6 features as input
        y.append(data[i + window_size, -1])         # predict normalized log_beta
    
    return np.array(X), np.array(y)

def load_and_prepare_data(df_dir, seeds_number, window_size, scaler = None):
    """
    Loads CSV files, applies shift(-2) for 'prev_I', computes log(Beta) for 'log_beta',
    and fits a global scaler on all 7 columns.
    Returns training sequences, targets, and the scaler.
    """
    if scaler == None:
        train_df = []
        
        # First pass: collect data for scaling
        for i in range(seeds_number):
            try:
                seed_df = pd.read_csv(df_dir + f'seir_seed_{i}.csv')
                seed_df['day'] = range(len(seed_df))
                seed_df['prev_I'] = seed_df['I'].shift(-2).fillna(0)
                seed_df['log_beta'] = np.log(seed_df['Beta'].clip(lower=1e-7))
                features = seed_df[['day','E', 'prev_I', 'log_beta']].values
                train_df.append(features)
            except Exception as e:
                print(f"Skipping seed {i}: {str(e)}")
                continue

        scaler = StandardScaler()
        if train_df:
            scaler.fit(np.concatenate(train_df))
        else:
            raise ValueError("No data collected for scaling. Please check your input files.")

    # Second pass: create training sequences
    all_X, all_y = [], []
    for i in range(seeds_number):
        try:
            seed_df = pd.read_csv(df_dir + f'seir_seed_{i}.csv')
            seed_df['day'] = range(len(seed_df))
            seed_df['prev_I'] = seed_df['I'].shift(-2).fillna(0)
            seed_df['log_beta'] = np.log(seed_df['Beta'].clip(lower=1e-7))
            features = seed_df[['day', 'E', 'prev_I', 'log_beta']].values
            scaled_features = scaler.transform(features)
            X, y = create_sequences(scaled_features, window_size)
            all_X.append(X)
            all_y.append(y)
        except Exception as e:
            print(f"Skipping seed {i}: {str(e)}")
            continue

    if not all_X or not all_y:
        raise ValueError("No valid training data found. Please check your input files.")

    return np.concatenate(all_X), np.concatenate(all_y), scaler

###############################################################################
# 2. Simplified model architecture with Grid search hyperparameters
###############################################################################
def build_lstm_model(window_size, n_features,
                     lstm_units1=64, lstm_units2=64,
                     dropout_rate1=0.2, dropout_rate2=0.3,
                     optimizer='rmsprop'):
    """
    Builds an LSTM model using the grid search best hyperparameters:
      - First LSTM layer units: 64 with recurrent dropout of 0.2
      - Second LSTM layer units: 64 with dropout of 0.3
      - Optimizer: rmsprop
    """
    inputs = Input(shape=(window_size, n_features))
    x = LSTM(lstm_units1, return_sequences=True, recurrent_dropout=dropout_rate1)(inputs)
    x = Dropout(dropout_rate1)(x)
    x = LSTM(lstm_units2, return_sequences=False)(x)
    x = Dropout(dropout_rate2)(x)
    outputs = Dense(1)(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=optimizer, loss='mse')
    return model

###############################################################################
# 3. Enhanced training configuration
###############################################################################
def lr_scheduler(epoch):
    """
    Applies learning rate decay after 20 epochs.
    """
    initial_lr = 0.001
    decay = 0.1 if epoch > 20 else 1.0
    return initial_lr * decay

def train_lstm_model(X_train, y_train, X_val, y_val, window_size):
    """
    Builds and trains the LSTM model with early stopping and a learning rate scheduler.
    """
    model = build_lstm_model(window_size, X_train.shape[2])
    early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=64,
        validation_data=(X_val, y_val),
        callbacks=[early_stop, LearningRateScheduler(lr_scheduler)],
        verbose=1
    )
    return model, history

###############################################################################
# 4. Training pipeline
###############################################################################
def train_and_save_model(train_df_dir, val_df_dir, seeds_number_train, seeds_number_val, model_save_path, scaler_save_path, window_size):
    print(f"Training LSTM model on {seeds_number_train} seeds...")
    start_time = time.time()
    
    X_train, y_train, scaler = load_and_prepare_data(train_df_dir, seeds_number_train, window_size)
    X_val, y_val, _ = load_and_prepare_data(val_df_dir, seeds_number_val, window_size, scaler = scaler)
    if len(X_train) == 0:
        raise ValueError("No valid training data found.")
    
    model, history = train_lstm_model(X_train, y_train, X_val, y_val, window_size)
    
    model.save(model_save_path)
    joblib.dump(scaler, scaler_save_path)
    
    training_time = time.time() - start_time
    print(f"Training completed in {training_time:.2f}s")
    
    # Plot training history
    plt.figure(figsize=(20,10))
    plt.plot(history.history['loss'], label='Train loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Training history')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    return model, scaler, training_time

train_dir = f'train/'
val_dir = f'val/'
seeds_number_train = 960
seeds_number_val = 240
window_size = 14   # Must be the same for training and simulation
model_file = 'lstm_day_E_prev_I_for_seir.keras'
scaler_file = 'lstm_day_E_prev_I_for_seir.pkl'
model, scaler, _ = train_and_save_model(
        train_dir, 
        val_dir,
        seeds_number_train=seeds_number_train, 
        seeds_number_val = seeds_number_val,
        model_save_path=model_file, 
        scaler_save_path=scaler_file, 
        window_size=window_size
    )
# Out:
# Training LSTM model on 960 seeds...
# Epoch 1/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 43s 11ms/step - loss: 0.4061 - val_loss: 0.4613 - learning_rate: 0.0010
# Epoch 2/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.3050 - val_loss: 0.2154 - learning_rate: 0.0010
# Epoch 3/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 0.2822 - val_loss: 0.2078 - learning_rate: 0.0010
# Epoch 4/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2741 - val_loss: 0.2185 - learning_rate: 0.0010
# Epoch 5/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2663 - val_loss: 0.2068 - learning_rate: 0.0010
# Epoch 6/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2607 - val_loss: 0.2052 - learning_rate: 0.0010
# Epoch 7/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2572 - val_loss: 0.2321 - learning_rate: 0.0010
# Epoch 8/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2533 - val_loss: 0.2471 - learning_rate: 0.0010
# Epoch 9/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2511 - val_loss: 0.2110 - learning_rate: 0.0010
# Epoch 10/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2513 - val_loss: 0.2007 - learning_rate: 0.0010
# Epoch 11/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2479 - val_loss: 0.1986 - learning_rate: 0.0010
# Epoch 12/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2466 - val_loss: 0.2018 - learning_rate: 0.0010
# Epoch 13/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2468 - val_loss: 0.2506 - learning_rate: 0.0010
# Epoch 14/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2436 - val_loss: 0.2207 - learning_rate: 0.0010
# Epoch 15/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2433 - val_loss: 0.2063 - learning_rate: 0.0010
# Epoch 16/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2434 - val_loss: 0.1964 - learning_rate: 0.0010
# Epoch 17/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2413 - val_loss: 0.2170 - learning_rate: 0.0010
# Epoch 18/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2419 - val_loss: 0.2224 - learning_rate: 0.0010
# Epoch 19/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2413 - val_loss: 0.1986 - learning_rate: 0.0010
# Epoch 20/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2391 - val_loss: 0.1992 - learning_rate: 0.0010
# Epoch 21/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2376 - val_loss: 0.1961 - learning_rate: 0.0010
# Epoch 22/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2176 - val_loss: 0.1888 - learning_rate: 1.0000e-04
# Epoch 23/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2145 - val_loss: 0.1876 - learning_rate: 1.0000e-04
# Epoch 24/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2110 - val_loss: 0.1872 - learning_rate: 1.0000e-04
# Epoch 25/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - loss: 0.2154 - val_loss: 0.1949 - learning_rate: 1.0000e-04
# Epoch 26/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2151 - val_loss: 0.1877 - learning_rate: 1.0000e-04
# Epoch 27/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2156 - val_loss: 0.1877 - learning_rate: 1.0000e-04
# Epoch 28/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2170 - val_loss: 0.1867 - learning_rate: 1.0000e-04
# Epoch 29/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2151 - val_loss: 0.1879 - learning_rate: 1.0000e-04
# Epoch 30/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2150 - val_loss: 0.1870 - learning_rate: 1.0000e-04
# Epoch 31/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2112 - val_loss: 0.1880 - learning_rate: 1.0000e-04
# Epoch 32/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2099 - val_loss: 0.1879 - learning_rate: 1.0000e-04
# Epoch 33/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - loss: 0.2148 - val_loss: 0.1867 - learning_rate: 1.0000e-04
# Epoch 34/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2116 - val_loss: 0.1880 - learning_rate: 1.0000e-04
# Epoch 35/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2156 - val_loss: 0.1880 - learning_rate: 1.0000e-04
# Epoch 36/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2140 - val_loss: 0.1914 - learning_rate: 1.0000e-04
# Epoch 37/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2160 - val_loss: 0.1873 - learning_rate: 1.0000e-04
# Epoch 38/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2145 - val_loss: 0.1860 - learning_rate: 1.0000e-04
# Epoch 39/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2129 - val_loss: 0.1858 - learning_rate: 1.0000e-04
# Epoch 40/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2138 - val_loss: 0.1858 - learning_rate: 1.0000e-04
# Epoch 41/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2134 - val_loss: 0.1855 - learning_rate: 1.0000e-04
# Epoch 42/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2146 - val_loss: 0.1848 - learning_rate: 1.0000e-04
# Epoch 43/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2130 - val_loss: 0.1849 - learning_rate: 1.0000e-04
# Epoch 44/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2145 - val_loss: 0.1852 - learning_rate: 1.0000e-04
# Epoch 45/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2148 - val_loss: 0.1847 - learning_rate: 1.0000e-04
# Epoch 46/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2128 - val_loss: 0.1873 - learning_rate: 1.0000e-04
# Epoch 47/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2128 - val_loss: 0.1876 - learning_rate: 1.0000e-04
# Epoch 48/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2116 - val_loss: 0.1853 - learning_rate: 1.0000e-04
# Epoch 49/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2161 - val_loss: 0.1849 - learning_rate: 1.0000e-04
# Epoch 50/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2108 - val_loss: 0.1860 - learning_rate: 1.0000e-04
# Epoch 51/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 9ms/step - loss: 0.2120 - val_loss: 0.1908 - learning_rate: 1.0000e-04
# Epoch 52/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2123 - val_loss: 0.1858 - learning_rate: 1.0000e-04
# Epoch 53/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2148 - val_loss: 0.1840 - learning_rate: 1.0000e-04
# Epoch 54/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2131 - val_loss: 0.1855 - learning_rate: 1.0000e-04
# Epoch 55/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2127 - val_loss: 0.1855 - learning_rate: 1.0000e-04
# Epoch 56/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2109 - val_loss: 0.1912 - learning_rate: 1.0000e-04
# Epoch 57/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2149 - val_loss: 0.1846 - learning_rate: 1.0000e-04
# Epoch 58/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2140 - val_loss: 0.1859 - learning_rate: 1.0000e-04
# Epoch 59/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2126 - val_loss: 0.1854 - learning_rate: 1.0000e-04
# Epoch 60/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2122 - val_loss: 0.1848 - learning_rate: 1.0000e-04
# Epoch 61/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2131 - val_loss: 0.1840 - learning_rate: 1.0000e-04
# Epoch 62/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2126 - val_loss: 0.1840 - learning_rate: 1.0000e-04
# Epoch 63/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2142 - val_loss: 0.1838 - learning_rate: 1.0000e-04
# Epoch 64/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 0.2131 - val_loss: 0.1843 - learning_rate: 1.0000e-04
# Epoch 65/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 0.2105 - val_loss: 0.1840 - learning_rate: 1.0000e-04
# Epoch 66/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2116 - val_loss: 0.1865 - learning_rate: 1.0000e-04
# Epoch 67/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2104 - val_loss: 0.1853 - learning_rate: 1.0000e-04
# Epoch 68/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2115 - val_loss: 0.1832 - learning_rate: 1.0000e-04
# Epoch 69/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2117 - val_loss: 0.1844 - learning_rate: 1.0000e-04
# Epoch 70/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 0.2137 - val_loss: 0.1829 - learning_rate: 1.0000e-04
# Epoch 71/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2148 - val_loss: 0.1847 - learning_rate: 1.0000e-04
# Epoch 72/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2120 - val_loss: 0.1849 - learning_rate: 1.0000e-04
# Epoch 73/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2094 - val_loss: 0.1854 - learning_rate: 1.0000e-04
# Epoch 74/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2125 - val_loss: 0.1839 - learning_rate: 1.0000e-04
# Epoch 75/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 0.2127 - val_loss: 0.1841 - learning_rate: 1.0000e-04
# Epoch 76/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2117 - val_loss: 0.1872 - learning_rate: 1.0000e-04
# Epoch 77/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2105 - val_loss: 0.1832 - learning_rate: 1.0000e-04
# Epoch 78/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 0.2132 - val_loss: 0.1885 - learning_rate: 1.0000e-04
# Epoch 79/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 0.2114 - val_loss: 0.1862 - learning_rate: 1.0000e-04
# Epoch 80/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2083 - val_loss: 0.1892 - learning_rate: 1.0000e-04
# Epoch 81/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2105 - val_loss: 0.1856 - learning_rate: 1.0000e-04
# Epoch 82/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2152 - val_loss: 0.1837 - learning_rate: 1.0000e-04
# Epoch 83/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 0.2092 - val_loss: 0.1829 - learning_rate: 1.0000e-04
# Epoch 84/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2123 - val_loss: 0.1832 - learning_rate: 1.0000e-04
# Epoch 85/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 0.2110 - val_loss: 0.1840 - learning_rate: 1.0000e-04
# Training completed in 3011.49s

# %%
###############################################################################
# 1. Data preparation
###############################################################################
def create_sequences(data, window_size):
    """
    Convert a multivariate sequence into samples of shape (window_size, n_features).
    The target is the last column (log_beta).
    """
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i : i + window_size, :-1])  # use first 6 features as input
        y.append(data[i + window_size, -1])         # predict normalized log_beta
    
    return np.array(X), np.array(y)

def load_and_prepare_data(df_dir, seeds_number, window_size, scaler = None):
    """
    Loads CSV files, applies shift(-2) for 'prev_I', computes log(Beta) for 'log_beta',
    and fits a global scaler on all 7 columns.
    Returns training sequences, targets, and the scaler.
    """
    if scaler == None:
        train_df = []
        
        # First pass: collect data for scaling
        for i in range(seeds_number):
            try:
                seed_df = pd.read_csv(df_dir + f'seir_seed_{i}.csv')
                seed_df['day'] = range(len(seed_df))
                seed_df['prev_I'] = seed_df['I'].shift(-2).fillna(0)
                seed_df['log_beta'] = np.log(seed_df['Beta'].clip(lower=1e-7))
                features = seed_df[['day','S','E','I','R', 'prev_I', 'log_beta']].values
                train_df.append(features)
            except Exception as e:
                print(f"Skipping seed {i}: {str(e)}")
                continue

        scaler = StandardScaler()
        if train_df:
            scaler.fit(np.concatenate(train_df))
        else:
            raise ValueError("No data collected for scaling. Please check your input files.")

    # Second pass: create training sequences
    all_X, all_y = [], []
    for i in range(seeds_number):
        try:
            seed_df = pd.read_csv(df_dir + f'seir_seed_{i}.csv')
            seed_df['day'] = range(len(seed_df))
            seed_df['prev_I'] = seed_df['I'].shift(-2).fillna(0)
            seed_df['log_beta'] = np.log(seed_df['Beta'].clip(lower=1e-7))
            features = seed_df[['day', 'S','E','I','R', 'prev_I', 'log_beta']].values
            scaled_features = scaler.transform(features)
            X, y = create_sequences(scaled_features, window_size)
            all_X.append(X)
            all_y.append(y)
        except Exception as e:
            print(f"Skipping seed {i}: {str(e)}")
            continue

    if not all_X or not all_y:
        raise ValueError("No valid training data found. Please check your input files.")

    return np.concatenate(all_X), np.concatenate(all_y), scaler

###############################################################################
# 2. Simplified model architecture with Grid search hyperparameters
###############################################################################
def build_lstm_model(window_size, n_features,
                     lstm_units1=64, lstm_units2=64,
                     dropout_rate1=0.2, dropout_rate2=0.3,
                     optimizer='rmsprop'):
    """
    Builds an LSTM model using the grid search best hyperparameters:
      - First LSTM layer units: 64 with recurrent dropout of 0.2
      - Second LSTM layer units: 64 with dropout of 0.3
      - Optimizer: rmsprop
    """
    inputs = Input(shape=(window_size, n_features))
    x = LSTM(lstm_units1, return_sequences=True, recurrent_dropout=dropout_rate1)(inputs)
    x = Dropout(dropout_rate1)(x)
    x = LSTM(lstm_units2, return_sequences=False)(x)
    x = Dropout(dropout_rate2)(x)
    outputs = Dense(1)(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=optimizer, loss='mse')
    return model

###############################################################################
# 3. Enhanced training configuration
###############################################################################
def lr_scheduler(epoch):
    """
    Applies learning rate decay after 20 epochs.
    """
    initial_lr = 0.001
    decay = 0.1 if epoch > 20 else 1.0
    return initial_lr * decay

def train_lstm_model(X_train, y_train, X_val, y_val, window_size):
    """
    Builds and trains the LSTM model with early stopping and a learning rate scheduler.
    """
    model = build_lstm_model(window_size, X_train.shape[2])
    early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=64,
        validation_data=(X_val, y_val),
        callbacks=[early_stop, LearningRateScheduler(lr_scheduler)],
        verbose=1
    )
    return model, history

###############################################################################
# 4. Training pipeline
###############################################################################
def train_and_save_model(train_df_dir, val_df_dir, seeds_number_train, seeds_number_val, model_save_path, scaler_save_path, window_size):
    print(f"Training LSTM model on {seeds_number_train} seeds...")
    start_time = time.time()
    
    X_train, y_train, scaler = load_and_prepare_data(train_df_dir, seeds_number_train, window_size)
    X_val, y_val, _ = load_and_prepare_data(val_df_dir, seeds_number_val, window_size, scaler = scaler)
    if len(X_train) == 0:
        raise ValueError("No valid training data found.")
    
    model, history = train_lstm_model(X_train, y_train, X_val, y_val, window_size)
    
    model.save(model_save_path)
    joblib.dump(scaler, scaler_save_path)
    
    training_time = time.time() - start_time
    print(f"Training completed in {training_time:.2f}s")
    
    # Plot training history
    plt.figure(figsize=(20,10))
    plt.plot(history.history['loss'], label='Train loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Training history')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    return model, scaler, training_time

train_dir = f'train/'
val_dir = f'val/'
seeds_number_train = 960
seeds_number_val = 240
window_size = 14   # Must be the same for training and simulation
model_file = 'lstm_day_SEIR_prev_I_for_seir.keras'
scaler_file = 'lstm_day_SEIR_prev_I_for_seir.pkl'
model, scaler, _ = train_and_save_model(
        train_dir, 
        val_dir,
        seeds_number_train=seeds_number_train, 
        seeds_number_val = seeds_number_val,
        model_save_path=model_file, 
        scaler_save_path=scaler_file, 
        window_size=window_size
    )
# Out:
# Training LSTM model on 960 seeds...
# Epoch 1/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 45s 12ms/step - loss: 0.2631 - val_loss: 0.1946 - learning_rate: 0.0010
# Epoch 2/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2291 - val_loss: 0.1902 - learning_rate: 0.0010
# Epoch 3/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2242 - val_loss: 0.1952 - learning_rate: 0.0010
# Epoch 4/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2223 - val_loss: 0.1906 - learning_rate: 0.0010
# Epoch 5/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2229 - val_loss: 0.1872 - learning_rate: 0.0010
# Epoch 6/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2249 - val_loss: 0.1879 - learning_rate: 0.0010
# Epoch 7/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2200 - val_loss: 0.1912 - learning_rate: 0.0010
# Epoch 8/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2191 - val_loss: 0.1838 - learning_rate: 0.0010
# Epoch 9/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 0.2179 - val_loss: 0.1906 - learning_rate: 0.0010
# Epoch 10/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2192 - val_loss: 0.1995 - learning_rate: 0.0010
# Epoch 11/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2181 - val_loss: 0.1839 - learning_rate: 0.0010
# Epoch 12/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - loss: 0.2173 - val_loss: 0.1845 - learning_rate: 0.0010
# Epoch 13/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2167 - val_loss: 0.1878 - learning_rate: 0.0010
# Epoch 14/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2196 - val_loss: 0.1854 - learning_rate: 0.0010
# Epoch 15/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - loss: 0.2161 - val_loss: 0.1862 - learning_rate: 0.0010
# Epoch 16/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2184 - val_loss: 0.1842 - learning_rate: 0.0010
# Epoch 17/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2184 - val_loss: 0.1850 - learning_rate: 0.0010
# Epoch 18/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2161 - val_loss: 0.1833 - learning_rate: 0.0010
# Epoch 19/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2164 - val_loss: 0.1861 - learning_rate: 0.0010
# Epoch 20/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2150 - val_loss: 0.1841 - learning_rate: 0.0010
# Epoch 21/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2162 - val_loss: 0.1866 - learning_rate: 0.0010
# Epoch 22/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2120 - val_loss: 0.1811 - learning_rate: 1.0000e-04
# Epoch 23/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2116 - val_loss: 0.1820 - learning_rate: 1.0000e-04
# Epoch 24/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2139 - val_loss: 0.1811 - learning_rate: 1.0000e-04
# Epoch 25/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2116 - val_loss: 0.1814 - learning_rate: 1.0000e-04
# Epoch 26/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 38s 11ms/step - loss: 0.2133 - val_loss: 0.1805 - learning_rate: 1.0000e-04
# Epoch 27/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2108 - val_loss: 0.1820 - learning_rate: 1.0000e-04
# Epoch 28/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2092 - val_loss: 0.1801 - learning_rate: 1.0000e-04
# Epoch 29/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2108 - val_loss: 0.1809 - learning_rate: 1.0000e-04
# Epoch 30/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2116 - val_loss: 0.1811 - learning_rate: 1.0000e-04
# Epoch 31/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 0.2123 - val_loss: 0.1810 - learning_rate: 1.0000e-04
# Epoch 32/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2112 - val_loss: 0.1811 - learning_rate: 1.0000e-04
# Epoch 33/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2102 - val_loss: 0.1815 - learning_rate: 1.0000e-04
# Epoch 34/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2086 - val_loss: 0.1800 - learning_rate: 1.0000e-04
# Epoch 35/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 0.2103 - val_loss: 0.1800 - learning_rate: 1.0000e-04
# Epoch 36/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - loss: 0.2144 - val_loss: 0.1797 - learning_rate: 1.0000e-04
# Epoch 37/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2097 - val_loss: 0.1815 - learning_rate: 1.0000e-04
# Epoch 38/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2089 - val_loss: 0.1809 - learning_rate: 1.0000e-04
# Epoch 39/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2108 - val_loss: 0.1806 - learning_rate: 1.0000e-04
# Epoch 40/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2081 - val_loss: 0.1804 - learning_rate: 1.0000e-04
# Epoch 41/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2092 - val_loss: 0.1802 - learning_rate: 1.0000e-04
# Epoch 42/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2092 - val_loss: 0.1829 - learning_rate: 1.0000e-04
# Epoch 43/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2086 - val_loss: 0.1803 - learning_rate: 1.0000e-04
# Epoch 44/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2093 - val_loss: 0.1810 - learning_rate: 1.0000e-04
# Epoch 45/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 39s 11ms/step - loss: 0.2085 - val_loss: 0.1792 - learning_rate: 1.0000e-04
# Epoch 46/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2106 - val_loss: 0.1807 - learning_rate: 1.0000e-04
# Epoch 47/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2108 - val_loss: 0.1799 - learning_rate: 1.0000e-04
# Epoch 48/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2105 - val_loss: 0.1791 - learning_rate: 1.0000e-04
# Epoch 49/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2082 - val_loss: 0.1807 - learning_rate: 1.0000e-04
# Epoch 50/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2095 - val_loss: 0.1795 - learning_rate: 1.0000e-04
# Epoch 51/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 0.2068 - val_loss: 0.1790 - learning_rate: 1.0000e-04
# Epoch 52/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2089 - val_loss: 0.1792 - learning_rate: 1.0000e-04
# Epoch 53/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2075 - val_loss: 0.1806 - learning_rate: 1.0000e-04
# Epoch 54/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2092 - val_loss: 0.1810 - learning_rate: 1.0000e-04
# Epoch 55/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2068 - val_loss: 0.1793 - learning_rate: 1.0000e-04
# Epoch 56/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2090 - val_loss: 0.1806 - learning_rate: 1.0000e-04
# Epoch 57/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 40s 11ms/step - loss: 0.2076 - val_loss: 0.1805 - learning_rate: 1.0000e-04
# Epoch 58/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 36s 10ms/step - loss: 0.2084 - val_loss: 0.1792 - learning_rate: 1.0000e-04
# Epoch 59/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2057 - val_loss: 0.1786 - learning_rate: 1.0000e-04
# Epoch 60/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2061 - val_loss: 0.1794 - learning_rate: 1.0000e-04
# Epoch 61/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2096 - val_loss: 0.1782 - learning_rate: 1.0000e-04
# Epoch 62/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2071 - val_loss: 0.1797 - learning_rate: 1.0000e-04
# Epoch 63/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2096 - val_loss: 0.1781 - learning_rate: 1.0000e-04
# Epoch 64/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2080 - val_loss: 0.1793 - learning_rate: 1.0000e-04
# Epoch 65/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 0.2074 - val_loss: 0.1790 - learning_rate: 1.0000e-04
# Epoch 66/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2037 - val_loss: 0.1800 - learning_rate: 1.0000e-04
# Epoch 67/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2114 - val_loss: 0.1789 - learning_rate: 1.0000e-04
# Epoch 68/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2095 - val_loss: 0.1799 - learning_rate: 1.0000e-04
# Epoch 69/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2082 - val_loss: 0.1815 - learning_rate: 1.0000e-04
# Epoch 70/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2101 - val_loss: 0.1795 - learning_rate: 1.0000e-04
# Epoch 71/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2096 - val_loss: 0.1793 - learning_rate: 1.0000e-04
# Epoch 72/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2099 - val_loss: 0.1779 - learning_rate: 1.0000e-04
# Epoch 73/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2092 - val_loss: 0.1799 - learning_rate: 1.0000e-04
# Epoch 74/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2089 - val_loss: 0.1789 - learning_rate: 1.0000e-04
# Epoch 75/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2098 - val_loss: 0.1800 - learning_rate: 1.0000e-04
# Epoch 76/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2106 - val_loss: 0.1772 - learning_rate: 1.0000e-04
# Epoch 77/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2075 - val_loss: 0.1792 - learning_rate: 1.0000e-04
# Epoch 78/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2074 - val_loss: 0.1779 - learning_rate: 1.0000e-04
# Epoch 79/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2085 - val_loss: 0.1797 - learning_rate: 1.0000e-04
# Epoch 80/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2077 - val_loss: 0.1784 - learning_rate: 1.0000e-04
# Epoch 81/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2108 - val_loss: 0.1781 - learning_rate: 1.0000e-04
# Epoch 82/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2069 - val_loss: 0.1803 - learning_rate: 1.0000e-04
# Epoch 83/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 32s 9ms/step - loss: 0.2057 - val_loss: 0.1783 - learning_rate: 1.0000e-04
# Epoch 84/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2085 - val_loss: 0.1777 - learning_rate: 1.0000e-04
# Epoch 85/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2117 - val_loss: 0.1792 - learning_rate: 1.0000e-04
# Epoch 86/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2101 - val_loss: 0.1799 - learning_rate: 1.0000e-04
# Epoch 87/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2096 - val_loss: 0.1779 - learning_rate: 1.0000e-04
# Epoch 88/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2095 - val_loss: 0.1789 - learning_rate: 1.0000e-04
# Epoch 89/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2074 - val_loss: 0.1774 - learning_rate: 1.0000e-04
# Epoch 90/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2061 - val_loss: 0.1788 - learning_rate: 1.0000e-04
# Epoch 91/100
# 3555/3555 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - loss: 0.2099 - val_loss: 0.1773 - learning_rate: 1.0000e-04
# Training completed in 3374.49s
