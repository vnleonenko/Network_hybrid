# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import time
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler

# %%
###############################################################################
# 1. Data preparation
###############################################################################
def create_sequences(data, window_size):
    """
    Convert a multivariate sequence into samples of shape (window_size, n_features).
    The target is the last column (log_beta).
    """
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i : i + window_size, :-1])  # use first 6 features as input
        y.append(data[i + window_size, -1])         # predict normalized log_beta
    
    return np.array(X), np.array(y)

def load_and_prepare_data(df_dir, seeds_number, window_size, scaler = None):
    """
    Loads CSV files, applies shift(-2) for 'prev_I', computes log(Beta) for 'log_beta',
    and fits a global scaler on all 7 columns.
    Returns training sequences, targets, and the scaler.
    """
    if scaler == None:
        train_df = []
        
        # First pass: collect data for scaling
        for i in range(seeds_number):
            try:
                seed_df = pd.read_csv(df_dir + f'seir_seed_{i}.csv')
                seed_df['day'] = range(len(seed_df))
                seed_df['prev_I'] = seed_df['I'].shift(-2).fillna(0)
                seed_df['log_beta'] = np.log(seed_df['Beta'].clip(lower=1e-7))
                seed_df = seed_df[(seed_df['E'] > 0)|(seed_df['I'] > 0)].copy()
                features = seed_df[['day','E', 'prev_I', 'log_beta']].values
                train_df.append(features)
            except Exception as e:
                print(f"Skipping seed {i}: {str(e)}")
                continue

        scaler = StandardScaler()
        if train_df:
            scaler.fit(np.concatenate(train_df))
        else:
            raise ValueError("No data collected for scaling. Please check your input files.")

    # Second pass: create training sequences
    all_X, all_y = [], []
    for i in range(seeds_number):
        try:
            seed_df = pd.read_csv(df_dir + f'seir_seed_{i}.csv')
            seed_df['day'] = range(len(seed_df))
            seed_df['prev_I'] = seed_df['I'].shift(-2).fillna(0)
            seed_df['log_beta'] = np.log(seed_df['Beta'].clip(lower=1e-7))
            seed_df = seed_df[(seed_df['E'] > 0)|(seed_df['I'] > 0)].copy()
            features = seed_df[['day', 'E', 'prev_I', 'log_beta']].values
            scaled_features = scaler.transform(features)
            X, y = create_sequences(scaled_features, window_size)
            all_X.append(X)
            all_y.append(y)
        except Exception as e:
            print(f"Skipping seed {i}: {str(e)}")
            continue

    if not all_X or not all_y:
        raise ValueError("No valid training data found. Please check your input files.")

    return np.concatenate(all_X), np.concatenate(all_y), scaler

###############################################################################
# 2. Simplified model architecture with Grid search hyperparameters
###############################################################################
def build_lstm_model(window_size, n_features,
                     lstm_units1=64, lstm_units2=64,
                     dropout_rate1=0.2, dropout_rate2=0.3,
                     optimizer='rmsprop'):
    """
    Builds an LSTM model using the grid search best hyperparameters:
      - First LSTM layer units: 64 with recurrent dropout of 0.2
      - Second LSTM layer units: 64 with dropout of 0.3
      - Optimizer: rmsprop
    """
    inputs = Input(shape=(window_size, n_features))
    x = LSTM(lstm_units1, return_sequences=True, recurrent_dropout=dropout_rate1)(inputs)
    x = Dropout(dropout_rate1)(x)
    x = LSTM(lstm_units2, return_sequences=False)(x)
    x = Dropout(dropout_rate2)(x)
    outputs = Dense(1)(x)
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=optimizer, loss='mse')
    return model

###############################################################################
# 3. Enhanced training configuration
###############################################################################
def lr_scheduler(epoch):
    """
    Applies learning rate decay after 20 epochs.
    """
    initial_lr = 0.001
    decay = 0.1 if epoch > 30 else 1.0
    return initial_lr * decay

def train_lstm_model(X_train, y_train, X_val, y_val, window_size):
    """
    Builds and trains the LSTM model with early stopping and a learning rate scheduler.
    """
    model = build_lstm_model(window_size, X_train.shape[2])
    early_stop = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)
    history = model.fit(
        X_train, y_train,
        epochs=100,
        batch_size=64,
        validation_data=(X_val, y_val),
        callbacks=[early_stop, LearningRateScheduler(lr_scheduler)],
        verbose=1
    )
    return model, history

###############################################################################
# 4. Training pipeline
###############################################################################
def train_and_save_model(train_df_dir, val_df_dir, seeds_number_train, seeds_number_val, model_save_path, scaler_save_path, window_size):
    print(f"Training LSTM model on {seeds_number_train} seeds...")
    start_time = time.time()
    
    X_train, y_train, scaler = load_and_prepare_data(train_df_dir, seeds_number_train, window_size)
    X_val, y_val, _ = load_and_prepare_data(val_df_dir, seeds_number_val, window_size, scaler = scaler)
    if len(X_train) == 0:
        raise ValueError("No valid training data found.")
    
    model, history = train_lstm_model(X_train, y_train, X_val, y_val, window_size)
    
    model.save(model_save_path)
    joblib.dump(scaler, scaler_save_path)
    
    training_time = time.time() - start_time
    print(f"Training completed in {training_time:.2f}s")
    
    # Plot training history
    plt.figure(figsize=(20,10))
    plt.plot(history.history['loss'], label='Train loss')
    plt.plot(history.history['val_loss'], label='Validation loss')
    plt.title('Training history')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    
    return model, scaler, training_time

train_dir = f'train/'
val_dir = f'val/'
seeds_number_train = 960
seeds_number_val = 240
window_size = 14   # Must be the same for training and simulation
model_file = 'lstm_day_E_prev_I_for_seir.keras'
scaler_file = 'lstm_day_E_prev_I_for_seir.pkl'
model, scaler, _ = train_and_save_model(
        train_dir, 
        val_dir,
        seeds_number_train=seeds_number_train, 
        seeds_number_val = seeds_number_val,
        model_save_path=model_file, 
        scaler_save_path=scaler_file, 
        window_size=window_size
    )
# Out:
# Training LSTM model on 960 seeds...
# Epoch 1/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 80s 23ms/step - loss: 0.3777 - val_loss: 0.4119 - learning_rate: 0.0010
# Epoch 2/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 67s 22ms/step - loss: 0.3183 - val_loss: 0.3110 - learning_rate: 0.0010
# Epoch 3/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 65s 21ms/step - loss: 0.3134 - val_loss: 0.3546 - learning_rate: 0.0010
# Epoch 4/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 63s 20ms/step - loss: 0.3111 - val_loss: 0.3072 - learning_rate: 0.0010
# Epoch 5/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 63s 20ms/step - loss: 0.3117 - val_loss: 0.3335 - learning_rate: 0.0010
# Epoch 6/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - loss: 0.3056 - val_loss: 0.3088 - learning_rate: 0.0010
# Epoch 7/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 50s 16ms/step - loss: 0.3008 - val_loss: 0.3002 - learning_rate: 0.0010
# Epoch 8/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 50s 16ms/step - loss: 0.3051 - val_loss: 0.3294 - learning_rate: 0.0010
# Epoch 9/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 16ms/step - loss: 0.3007 - val_loss: 0.3003 - learning_rate: 0.0010
# Epoch 10/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 17ms/step - loss: 0.3048 - val_loss: 0.3454 - learning_rate: 0.0010
# Epoch 11/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 17ms/step - loss: 0.3063 - val_loss: 0.3270 - learning_rate: 0.0010
# Epoch 12/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.3029 - val_loss: 0.3135 - learning_rate: 0.0010
# Epoch 13/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 17ms/step - loss: 0.3049 - val_loss: 0.2982 - learning_rate: 0.0010
# Epoch 14/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.3034 - val_loss: 0.3071 - learning_rate: 0.0010
# Epoch 15/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 16ms/step - loss: 0.3046 - val_loss: 0.3211 - learning_rate: 0.0010
# Epoch 16/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 17ms/step - loss: 0.3037 - val_loss: 0.3002 - learning_rate: 0.0010
# Epoch 17/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 53s 17ms/step - loss: 0.3046 - val_loss: 0.2998 - learning_rate: 0.0010
# Epoch 18/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 53s 17ms/step - loss: 0.2991 - val_loss: 0.3074 - learning_rate: 0.0010
# Epoch 19/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.3057 - val_loss: 0.3055 - learning_rate: 0.0010
# Epoch 20/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.3000 - val_loss: 0.2984 - learning_rate: 0.0010
# Epoch 21/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.3031 - val_loss: 0.2997 - learning_rate: 0.0010
# Epoch 22/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.3015 - val_loss: 0.3006 - learning_rate: 0.0010
# Epoch 23/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2976 - val_loss: 0.3004 - learning_rate: 0.0010
# Epoch 24/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 17ms/step - loss: 0.3014 - val_loss: 0.3234 - learning_rate: 0.0010
# Epoch 25/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 56s 18ms/step - loss: 0.3024 - val_loss: 0.2988 - learning_rate: 0.0010
# Epoch 26/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.3045 - val_loss: 0.2990 - learning_rate: 0.0010
# Epoch 27/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 54s 17ms/step - loss: 0.3017 - val_loss: 0.2997 - learning_rate: 0.0010
# Epoch 28/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 54s 17ms/step - loss: 0.3000 - val_loss: 0.2982 - learning_rate: 0.0010
# Epoch 29/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 17ms/step - loss: 0.3036 - val_loss: 0.3057 - learning_rate: 0.0010
# Epoch 30/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.3004 - val_loss: 0.3002 - learning_rate: 0.0010
# Epoch 31/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.3000 - val_loss: 0.3020 - learning_rate: 0.0010
# Epoch 32/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2974 - val_loss: 0.2969 - learning_rate: 1.0000e-04
# Epoch 33/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 17ms/step - loss: 0.2936 - val_loss: 0.2971 - learning_rate: 1.0000e-04
# Epoch 34/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2938 - val_loss: 0.2987 - learning_rate: 1.0000e-04
# Epoch 35/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2997 - val_loss: 0.2974 - learning_rate: 1.0000e-04
# Epoch 36/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 17ms/step - loss: 0.2990 - val_loss: 0.2970 - learning_rate: 1.0000e-04
# Epoch 37/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2952 - val_loss: 0.2979 - learning_rate: 1.0000e-04
# Epoch 38/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2981 - val_loss: 0.2980 - learning_rate: 1.0000e-04
# Epoch 39/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2967 - val_loss: 0.2977 - learning_rate: 1.0000e-04
# Epoch 40/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2991 - val_loss: 0.2969 - learning_rate: 1.0000e-04
# Epoch 41/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 54s 17ms/step - loss: 0.2975 - val_loss: 0.2968 - learning_rate: 1.0000e-04
# Epoch 42/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2954 - val_loss: 0.2968 - learning_rate: 1.0000e-04
# Epoch 43/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 53s 17ms/step - loss: 0.2963 - val_loss: 0.2967 - learning_rate: 1.0000e-04
# Epoch 44/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 51s 17ms/step - loss: 0.2968 - val_loss: 0.2975 - learning_rate: 1.0000e-04
# Epoch 45/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2975 - val_loss: 0.2966 - learning_rate: 1.0000e-04
# Epoch 46/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2942 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 47/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2972 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 48/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2941 - val_loss: 0.2964 - learning_rate: 1.0000e-04
# Epoch 49/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2930 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 50/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2972 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 51/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 53s 17ms/step - loss: 0.2955 - val_loss: 0.2967 - learning_rate: 1.0000e-04
# Epoch 52/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 54s 17ms/step - loss: 0.2960 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 53/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 53s 17ms/step - loss: 0.2924 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 54/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2956 - val_loss: 0.2966 - learning_rate: 1.0000e-04
# Epoch 55/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2990 - val_loss: 0.2968 - learning_rate: 1.0000e-04
# Epoch 56/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2970 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 57/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 53s 17ms/step - loss: 0.2979 - val_loss: 0.2969 - learning_rate: 1.0000e-04
# Epoch 58/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 53s 17ms/step - loss: 0.2963 - val_loss: 0.2970 - learning_rate: 1.0000e-04
# Epoch 59/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 53s 17ms/step - loss: 0.2990 - val_loss: 0.2974 - learning_rate: 1.0000e-04
# Epoch 60/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2959 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 61/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2960 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 62/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2985 - val_loss: 0.2965 - learning_rate: 1.0000e-04
# Epoch 63/100
# 3093/3093 ━━━━━━━━━━━━━━━━━━━━ 52s 17ms/step - loss: 0.2977 - val_loss: 0.2992 - learning_rate: 1.0000e-04
# Training completed in 3381.74s
